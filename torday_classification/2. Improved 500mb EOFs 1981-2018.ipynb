# %%
import xarray as xr
import numpy as np
import pandas as pd
import cartopy.crs as ccrs
from eofs.xarray import Eof

import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append('..')
from plotting.maps import CartopyMap
from plotting.mapareas import conus
from reanalysis.ncep_r1 import daily4x

# %%
def generate_dates(years, months, days):
    for year in years:
        for month in months:
            for day in days:
                yield pd.Timestamp(year, month, day)

# %%
years = range(1981, 2019)
months = [5]
days = range(16, 32)

dates = [ts + pd.Timedelta('1 day') for ts in generate_dates(years, months, days)]

# %%
len(dates)
# Out:
# 608

# %%
ds = daily4x.hgt(dates, level=500)
ds_mean = ds.mean()
ds_anom = ds - ds_mean

# %%
ds_anom_conus = ds_anom.geospatial.domain(*tuple(conus))

# %%
ds_anom_conus
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 12, lon: 25, time: 608)
# Coordinates:
#     level    float32 500.0
#   * lon      (lon) float32 -127.5 -125.0 -122.5 -120.0 ... -72.5 -70.0 -67.5
#   * lat      (lat) float32 50.0 47.5 45.0 42.5 40.0 ... 32.5 30.0 27.5 25.0 22.5
#   * time     (time) datetime64[ns] 1981-05-17 1981-05-18 ... 2018-06-01
# Data variables:
#     hgt      (time, lat, lon) float32 38.970215 58.970215 ... 361.9702 353.9702

# %%
coslat = np.cos(np.deg2rad(ds_anom_conus.coords['lat'].values)).clip(0., 1.)
wgts = np.sqrt(coslat)[..., np.newaxis]
solver = Eof(ds_anom_conus.hgt, weights=wgts)

# %%
eofs = solver.eofsAsCorrelation()
pcs = solver.pcs()

# %%
def plot_eofs(eofs, nrows, ncols, proj, bbox, clevs=None):
    if clevs is None:
        clevs = np.linspace(-1, 1, 20)
    
    for i in range(nrows * ncols):
        ax = plt.subplot(nrows, ncols, i + 1, projection=proj)
        bgmap = CartopyMap.from_axes(ax, bbox=bbox)
        bgmap.draw()
        eofs[i].plot.contourf(ax=bgmap.ax, cmap=plt.cm.RdBu_r, levels=clevs,
                                 transform=ccrs.PlateCarree(), add_colorbar=False)
        ax.set_aspect('equal')
        
    plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.figure(figsize=(30, 20))
plot_eofs(eofs, 2, 2, proj=ccrs.Mercator(), bbox=conus)

# %%
firstfivepcs = pcs.sel(mode=slice(0, 9)).to_dataframe().reset_index()
firstfivepcs.rename(columns={'time': 'date'}, inplace=True)

# %%
torsyn = pd.read_csv('./tordays_chasealley.csv', parse_dates=['date'])
tors_pcs = firstfivepcs.merge(torsyn, on='date', how='inner')

# %%
tors_pcs.head(10)
# Out:
#         date  mode         pcs    tor
# 0 1985-05-17     0  636.520203  False
# 1 1985-05-17     1   27.602900  False
# 2 1985-05-17     2 -215.677383  False
# 3 1985-05-17     3 -231.101639  False
# 4 1985-05-17     4 -188.532608  False
# 5 1985-05-17     5 -497.950714  False
# 6 1985-05-17     6  276.913605  False
# 7 1985-05-17     7 -154.750320  False
# 8 1985-05-17     8   81.087318  False
# 9 1985-05-17     9 -216.620331  False

# %%
# tors_pcs.to_csv('./tors_10pcs_2.csv', index=False)
