# %%
# %env WORKDIR=~/weatherpy-work
from stormevents.io import load_tornadoes

import numpy as np
import pandas as pd
import geopy.distance
# Out:
# env: WORKDIR=~/weatherpy-work

# %%
sample_data = load_tornadoes('1991-04-26 12:00', '1991-04-27 12:00', tz='GMT')

# %%
sample_data.columns
# Out:
# Index(['begin_yearmonth', 'begin_day', 'begin_time', 'end_yearmonth',
#        'end_day', 'end_time', 'episode_id', 'event_id', 'state', 'state_fips',
#        'year', 'month_name', 'event_type', 'cz_type', 'cz_fips', 'cz_name',
#        'wfo', 'begin_date_time', 'cz_timezone', 'end_date_time',
#        'injuries_direct', 'injuries_indirect', 'deaths_direct',
#        'deaths_indirect', 'damage_property', 'damage_crops', 'source',
#        'magnitude', 'magnitude_type', 'flood_cause', 'category', 'tor_f_scale',
#        'tor_length', 'tor_width', 'tor_other_wfo', 'tor_other_cz_state',
#        'tor_other_cz_fips', 'tor_other_cz_name', 'begin_range',
#        'begin_azimuth', 'begin_location', 'end_range', 'end_azimuth',
#        'end_location', 'begin_lat', 'begin_lon', 'end_lat', 'end_lon',
#        'episode_narrative', 'event_narrative', 'data_source'],
#       dtype='object')

# %%
sample_data.head()
# Out:
#   begin_yearmonth  begin_day begin_time end_yearmonth  end_day end_time  \
# 0          199104         26       2230        199104       26     2230
# 1          199104         27       0133        199104       27     0133
# 2          199104         27       0300        199104       27     0300
# 3          199104         26       1545        199104       26     1545
# 4          199104         27       0245        199104       27     0245
#
#    episode_id  event_id     state  state_fips  ...  end_range end_azimuth  \
# 0         NaN  10034558    KANSAS          20  ...          0         NaN
# 1         NaN  10034585    KANSAS          20  ...          0         NaN
# 2         NaN  10137290     TEXAS          48  ...          0         NaN
# 3         NaN  10034309    KANSAS          20  ...          0         NaN
# 4         NaN  10102365  OKLAHOMA          40  ...          0         NaN
#
#   end_location begin_lat  begin_lon end_lat end_lon episode_narrative  \
# ...

# %%
def dist(lat1, lon1, lat2, lon2):
    if any(map(np.isnan, (lat1, lon1, lat2, lon2))):
        return np.nan
    pt1 = (lat1, lon1)
    pt2 = (lat2, lon2)
    return geopy.distance.distance(pt1, pt2).mi

sample_data['calc_length'] = sample_data.apply(
    lambda r: dist(r.begin_lat, r.begin_lon, r.end_lat, r.end_lon), axis=1)

# %%
sample_data[
    ['begin_date_time', 'end_date_time', 'begin_lat', 'begin_lon', 'end_lat', 'end_lon', 'tor_length', 'calc_length', 'tor_f_scale', 'state']]
# Out:
#        begin_date_time       end_date_time  begin_lat  begin_lon  end_lat  \
# 0  1991-04-26 22:30:00 1991-04-26 22:30:00      37.18     -97.83    37.23
# 1  1991-04-27 01:33:00 1991-04-27 01:33:00      37.58     -97.33      NaN
# 2  1991-04-27 03:00:00 1991-04-27 03:00:00      33.63     -95.27      NaN
# 3  1991-04-26 15:45:00 1991-04-26 15:45:00      37.27     -95.55    37.37
# 4  1991-04-27 02:45:00 1991-04-27 02:45:00      36.45     -95.72    36.48
# 5  1991-04-27 03:10:00 1991-04-27 03:10:00      36.53     -95.43      NaN
# 6  1991-04-27 01:27:00 1991-04-27 01:27:00      36.67     -96.53      NaN
# 7  1991-04-27 01:36:00 1991-04-27 01:36:00      36.20     -96.28    36.38
# 8  1991-04-26 23:00:00 1991-04-26 23:00:00      36.40     -97.77    36.43
# 9  1991-04-26 23:15:00 1991-04-26 23:15:00      36.43     -97.60      NaN
# 10 1991-04-26 23:30:00 1991-04-26 23:30:00      36.43     -97.55    36.45
# 11 1991-04-26 23:38:00 1991-04-26 23:38:00      36.45     -97.43    36.57
# ...
